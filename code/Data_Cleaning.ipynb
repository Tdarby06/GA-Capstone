# %%
import numpy as np
import pandas as pd
pd.options.display.min_rows = 63

# %%
def season_cleaner(team_df):
    season_list = [1995, 1996, 1997, 1998, 1999,
                   2000, 2001, 2002, 2003, 2004, 
                   2005, 2006, 2007, 2008, 2009,
                   2010, 2011, 2012, 2013, 2014,
                   2015, 2016, 2017, 2018, 2019]
    team_seasons = []
    for season in season_list:
        #converts date column to datetimeobject
        team_df['date'] = pd.to_datetime(team_df['date'])
        df = team_df[team_df['date'].dt.year == season].copy()
        #datetime setup
        df['year'] = df['date'].dt.year
        df['month'] = df['date'].dt.month
        df['day'] = df['date'].dt.day
        df['weekday'] = df['date'].dt.weekday
        df['weekday_name'] = df['date'].dt.weekday_name
        wins = []
        losses = []
        for wl in df['record']:
            w, l = wl.split('-')
            wins.append(int(w))
            losses.append(int(l))
        df['wins'] = wins
        df['losses'] = losses
        df['total_games'] = df['wins'] + df['losses']
        df['win_pct'] = df['wins'] / df['total_games']
        #drop attendance nan value rows
        df.dropna(subset=['attendance'], inplace=True)
        #attendance convert from string to int
        df['attendance'] = df['attendance'].str.replace(',', '').astype(int)
        ### streak convert ####
        df['streak'].fillna('0', inplace=True)
        df['streak'] = [len(x) if '+' in x else -len(x) if '-' in x else 0 for x in df['streak']]
        #games back convert
        df['games_back'] = [0. if x == ' Tied' or x == '0'else float(x.replace('up', '')) if 'up' in x else -float(x) for x in df['games_back']]
        # average runs per game feature
        df['runs_pg_avg'] = [0 if x == min(df['date']) else df[df['date'] < x].r.astype(int).mean() for x in df['date']]
        #5 game moving runs average 
        df['runs_mavg_5'] = df['r'].rolling(5).mean().shift()
        # 5 game moving runs against average
        df['runs_against_mavg_5'] = df['ra'].rolling(5).mean().shift()
        #ten game moving win percentage
        ten_game_win_perc = [list(df['win_loss'][i-10:i]).count('W') / 10. for i in range(10, len(df))]
        for i in range(10):
            ten_game_win_perc.insert(0, None)
        df['ten_game_win_perc'] = ten_game_win_perc
        # 5 game era moving average
        df['era_mavg_5'] = df['pitch_era'].rolling(5).mean().shift()
        # 5 game batting average moving average
        df['bat_avg_mavg_5'] = df['bat_batting_avg'].rolling(5).mean().shift()
        # 5 game bat ops moving average
        df['ops_mavg_5'] = df['bat_ops'].rolling(5).mean().shift()
        # average hits per game
        df['hits_pg_avg'] = [0 if x == min(df['date']) else df[df['date'] < x].bat_hits.mean() for x in df['date']]
        # 5 game hits moving average
        df['hits_mavg_5'] = df['bat_hits'].rolling(5).mean().shift()
        # batting strike outs per game
        df['bat_stkout_pg_avg'] = [0 if x == min(df['date']) else df[df['date'] < x].bat_strike_outs.mean() for x in df['date']]
        # pitching strikeout per game
        df['ptich_stkout_pg_avg'] = [0 if x == min(df['date']) else df[df['date'] < x].pitch_strike_outs.mean() for x in df['date']]
        # 5 game pitching strikeout moving average
        df['pitch_strkout_mavg_5'] = df['pitch_strike_outs'].rolling(5).mean().shift()
        # opening day dummy
        df['opening_day'] = [1 if x == min(df['date']) else 0 for x in df['date']]
        #night game dummy
        df['night_game'] = [1 if x == 'N' else 0 for x in df['day_night']]
        #fill nan values created by the rolling means with values from the same column
        df['runs_mavg_5'] = [df.iloc[i].r if np.isnan(j) else j for i, j in enumerate(df['runs_mavg_5'])]
        df['runs_against_mavg_5'] = [df.iloc[i].ra if np.isnan(j) else j for i, j in enumerate(df['runs_against_mavg_5'])]
        df['ten_game_win_perc'] = [df.iloc[i].win_pct if np.isnan(j) else j for i, j in enumerate(df['ten_game_win_perc'])]
        df['era_mavg_5'] = [df.iloc[i].pitch_era if np.isnan(j) else j for i, j in enumerate(df['era_mavg_5'])]
        df['bat_avg_mavg_5'] = [df.iloc[i].bat_batting_avg if np.isnan(j) else j for i, j in enumerate(df['bat_avg_mavg_5'])]
        df['ops_mavg_5'] = [df.iloc[i].bat_ops if np.isnan(j) else j for i, j in enumerate(df['ops_mavg_5'])]
        df['hits_mavg_5'] = [df.iloc[i].bat_hits if np.isnan(j) else j for i, j in enumerate(df['hits_mavg_5'])]
        df['pitch_strkout_mavg_5'] = [df.iloc[i].pitch_strike_outs if np.isnan(j) else j for i, j in enumerate(df['pitch_strkout_mavg_5'])]
        #drop all away games from season data
        df['home_away'].fillna('home',inplace=True)
        df = df[~df['home_away'].str.contains('@')].reset_index(drop=True)

        team_seasons.append(df)
        print(f'{season} done')
    club = pd.concat(team_seasons)
    print('name for file:')
    a = input()
    club.to_csv(f'../data/clean_data/{a}_clean.csv', index=False)
        
    return print(f'all seasons for {a} done.')

# %%
houston = pd.read_csv('../data/pre_clean_data/HOU/houston_pc.csv')

# %%
# %time season_cleaner(houston)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# houston
# all seasons for       game#        day       date team home_away  opp win_loss     r    ra  \
# 0         1  Wednesday 1995-04-26  HOU         @  SDP        W  10.0   2.0
# 1         2   Thursday 1995-04-27  HOU         @  SDP        L   1.0  13.0
# 2         3     Friday 1995-04-28  HOU       NaN  COL        L   1.0   2.0
# 3         4   Saturday 1995-04-29  HOU       NaN  COL        L   1.0   2.0
# 4         5     Sunday 1995-04-30  HOU       NaN  COL        W   3.0   1.0
# 5         6    Tuesday 1995-05-02  HOU         @  CHC        W   5.0   2.0
# 6         7  Wednesday 1995-05-03  HOU         @  CHC        W  11.0   2.0
# 7         8   Thursday 1995-05-04  HOU         @  STL        W   6.0   4.0
# 8         9     Friday 1995-05-05  HOU         @  STL        W   9.0   4.0
# 9        10   Saturday 1995-05-06  HOU         @  STL        L   5.0   7.0
# 10       11     Sunday 1995-05-07  HOU         @  STL        L   5.0   6.0
# 11       12     Monday 1995-05-08  HOU         @  PIT        W   6.0   3.0
# 12       13    Tuesday 1995-05-09  HOU         @  PIT        W  13.0   6.0
# 13       14   Thursday 1995-05-11  HOU         @  PIT        W  12.0   4.0
# 14       15     Friday 1995-05-12  HOU       NaN  PHI        L   2.0   5.0
# 15       16   Saturday 1995-05-13  HOU       NaN  PHI        L   5.0   7.0
# 16       17     Sunday 1995-05-14  HOU       NaN  PHI        L   2.0   5.0
# 17       18    Tuesday 1995-05-16  HOU       NaN  NYM        L   0.0   1.0
# 18       19  Wednesday 1995-05-17  HOU       NaN  NYM        W   7.0   2.0
# 19       20   Thursday 1995-05-18  HOU       NaN  NYM        L   1.0   8.0
# 20       21     Friday 1995-05-19  HOU       NaN  MON        W  10.0   2.0
# 21       22   Saturday 1995-05-20  HOU       NaN  MON     W-wo   2.0   1.0
# 22       23     Sunday 1995-05-21  HOU       NaN  MON        W   5.0   2.0
# 23       24     Monday 1995-05-22  HOU         @  CIN     L-wo   2.0   3.0
# 24       25    Tuesday 1995-05-23  HOU         @  CIN        L   5.0  10.0
# 25       26  Wednesday 1995-05-24  HOU         @  CIN        L   2.0   4.0
# 26       27     Friday 1995-05-26  HOU       NaN  ATL        L   3.0   8.0
# 27       28   Saturday 1995-05-27  HOU       NaN  ATL     W-wo   3.0   2.0
# 28       29     Sunday 1995-05-28  HOU       NaN  ATL        L   1.0   3.0
# 29       30     Monday 1995-05-29  HOU         @  FLA        L   7.0   9.0
# ...     ...        ...        ...  ...       ...  ...      ...   ...   ...
# 4002    133    Tuesday 2019-08-27  HOU       NaN  TBR        W  15.0   1.0
# 4003    134  Wednesday 2019-08-28  HOU       NaN  TBR        W   8.0   6.0
# 4004    135   Thursday 2019-08-29  HOU       NaN  TBR        L   8.0   9.0
# 4005    136     Friday 2019-08-30  HOU         @  TOR        W   7.0   4.0
# 4006    137   Saturday 2019-08-31  HOU         @  TOR        L   4.0   6.0
# 4007    138     Sunday 2019-09-01  HOU         @  TOR        W   2.0   0.0
# 4008    139     Monday 2019-09-02  HOU         @  MIL        W   3.0   2.0
# 4009    140    Tuesday 2019-09-03  HOU         @  MIL        L   2.0   4.0
# 4010    141   Thursday 2019-09-05  HOU       NaN  SEA     W-wo  11.0   9.0
# 4011    142     Friday 2019-09-06  HOU       NaN  SEA        W   7.0   4.0
# 4012    143   Saturday 2019-09-07  HOU       NaN  SEA        W   2.0   1.0
# 4013    144     Sunday 2019-09-08  HOU       NaN  SEA        W  21.0   1.0
# 4014    145     Monday 2019-09-09  HOU       NaN  OAK        W  15.0   0.0
# 4015    146    Tuesday 2019-09-10  HOU       NaN  OAK        L   7.0  21.0
# 4016    147  Wednesday 2019-09-11  HOU       NaN  OAK        L   3.0   5.0
# 4017    148   Thursday 2019-09-12  HOU       NaN  OAK        L   2.0   3.0
# 4018    149     Friday 2019-09-13  HOU         @  KCR        W   4.0   1.0
# 4019    150   Saturday 2019-09-14  HOU         @  KCR        W   6.0   1.0
# 4020    151     Sunday 2019-09-15  HOU         @  KCR        W  12.0   3.0
# 4021    152    Tuesday 2019-09-17  HOU       NaN  TEX        W   4.0   1.0
# 4022    153  Wednesday 2019-09-18  HOU       NaN  TEX        W   3.0   2.0
# 4023    154     Friday 2019-09-20  HOU       NaN  LAA        W   6.0   4.0
# 4024    155   Saturday 2019-09-21  HOU       NaN  LAA        L   4.0   8.0
# 4025    156     Sunday 2019-09-22  HOU       NaN  LAA        W  13.0   5.0
# 4026    157    Tuesday 2019-09-24  HOU         @  SEA        W   3.0   0.0
# 4027    158  Wednesday 2019-09-25  HOU         @  SEA        W   3.0   0.0
# 4028    159   Thursday 2019-09-26  HOU         @  LAA     L-wo   3.0   4.0
# 4029    160     Friday 2019-09-27  HOU         @  LAA        W   4.0   0.0
# 4030    161   Saturday 2019-09-28  HOU         @  LAA        W   6.0   3.0
# 4031    162     Sunday 2019-09-29  HOU         @  LAA        W   8.0   5.0
#
#       innings  ... pitch_strike_outs  pitch_opp_hr pitch_era  \
# 0         NaN  ...               8.0           0.0      1.00
# 1         NaN  ...               8.0           1.0      9.00
# 2         NaN  ...               6.0           1.0      2.00
# 3         NaN  ...               8.0           0.0      2.00
# 4         NaN  ...              12.0           1.0      1.00
# 5         NaN  ...               5.0           0.0      1.00
# 6         NaN  ...               5.0           0.0      2.00
# 7         NaN  ...               8.0           1.0      3.00
# 8         NaN  ...               7.0           0.0      3.00
# 9         NaN  ...               5.0           2.0      7.88
# 10        NaN  ...               7.0           0.0      6.75
# 11        NaN  ...               8.0           0.0      3.00
# 12        NaN  ...               8.0           1.0      6.00
# 13        NaN  ...               3.0           1.0      2.00
# 14        NaN  ...               5.0           0.0      5.00
# 15        NaN  ...               2.0           0.0      5.00
# 16        NaN  ...               6.0           1.0      5.00
# 17        NaN  ...               5.0           0.0      1.00
# 18        NaN  ...               4.0           1.0      2.00
# 19        NaN  ...               8.0           1.0      8.00
# 20        NaN  ...              10.0           0.0      2.00
# 21       10.0  ...              13.0           0.0      0.90
# 22        NaN  ...               6.0           0.0      2.00
# 23       10.0  ...               7.0           3.0      3.00
# 24        NaN  ...               5.0           0.0     11.25
# 25        NaN  ...               7.0           1.0      4.50
# 26        NaN  ...               9.0           3.0      7.00
# 27       10.0  ...              13.0           0.0      1.80
# 28        NaN  ...               8.0           1.0      3.00
# 29        NaN  ...               8.0           1.0     10.12
# ...       ...  ...               ...           ...       ...
# 4002      NaN  ...               5.0           1.0      1.00
# 4003      NaN  ...              19.0           2.0      6.00
# 4004      NaN  ...              11.0           2.0      9.00
# 4005      NaN  ...              10.0           3.0      3.00
# 4006      NaN  ...               7.0           2.0      6.75
# 4007      NaN  ...              14.0           0.0      0.00
# 4008     10.0  ...              20.0           2.0      1.80
# 4009      NaN  ...               5.0           1.0      4.50
# 4010     13.0  ...              15.0           4.0      6.23
# 4011      NaN  ...              11.0           1.0      4.00
# 4012      NaN  ...              10.0           0.0      1.00
# 4013      NaN  ...              17.0           1.0      1.00
# 4014      NaN  ...              10.0           0.0      0.00
# 4015      NaN  ...               7.0           6.0     21.00
# 4016      NaN  ...              16.0           2.0      5.00
# 4017      NaN  ...              17.0           1.0      3.00
# 4018      NaN  ...              12.0           0.0      0.00
# 4019      NaN  ...              10.0           0.0      1.00
# 4020      NaN  ...               7.0           0.0      3.00
# 4021      NaN  ...              12.0           1.0      1.00
# 4022      NaN  ...              11.0           1.0      2.00
# 4023      NaN  ...              11.0           1.0      4.00
# 4024      NaN  ...              10.0           2.0      8.00
# 4025      NaN  ...              10.0           0.0      4.00
# 4026      NaN  ...              18.0           0.0      0.00
# 4027      NaN  ...              10.0           0.0      0.00
# 4028     12.0  ...               7.0           0.0      2.31
# 4029      NaN  ...               7.0           0.0      0.00
# 4030      NaN  ...              13.0           2.0      3.00
# 4031      NaN  ...              15.0           2.0      5.00
#
#      pitch_batters_faced pitch_total_pitches pitch_combined_strikes  \
# 0                   38.0               147.0                   97.0
# 1                   47.0               148.0                   94.0
# 2                   32.0                 NaN                    NaN
# 3                   33.0               133.0                   83.0
# 4                   33.0               115.0                   78.0
# 5                   39.0               149.0                   89.0
# 6                   33.0               117.0                   71.0
# 7                   42.0                 NaN                    NaN
# 8                   37.0               118.0                   85.0
# 9                   34.0               111.0                   72.0
# 10                  35.0               145.0                   86.0
# 11                  38.0               133.0                   78.0
# 12                  36.0               113.0                   77.0
# 13                  38.0               141.0                   82.0
# 14                  44.0               171.0                   88.0
# 15                  45.0               179.0                   97.0
# 16                  41.0               151.0                   88.0
# 17                  30.0                88.0                   60.0
# 18                  35.0               117.0                   76.0
# 19                  41.0               152.0                   93.0
# 20                  35.0                 NaN                    NaN
# 21                  38.0                 NaN                    NaN
# 22                  35.0               119.0                   77.0
# 23                  40.0               150.0                   93.0
# 24                  42.0               161.0                   84.0
# 25                  36.0               131.0                   83.0
# 26                  43.0               169.0                   96.0
# 27                  36.0               136.0                   85.0
# 28                  39.0               148.0                   85.0
# 29                  44.0               184.0                  118.0
# ...                  ...                 ...                    ...
# 4002                38.0               152.0                   93.0
# 4003                36.0               153.0                  105.0
# 4004                43.0               155.0                  106.0
# 4005                41.0               193.0                  112.0
# 4006                37.0               139.0                   86.0
# 4007                28.0               120.0                   79.0
# 4008                40.0               171.0                  111.0
# 4009                34.0               133.0                   86.0
# 4010                54.0               230.0                  154.0
# 4011                39.0               159.0                   95.0
# 4012                32.0               133.0                   94.0
# 4013                28.0               107.0                   75.0
# 4014                30.0               119.0                   79.0
# 4015                56.0               200.0                  134.0
# 4016                38.0               173.0                  106.0
# 4017                35.0               144.0                   98.0
# 4018                33.0               114.0                   80.0
# 4019                34.0               147.0                   96.0
# 4020                41.0               147.0                   95.0
# 4021                32.0               130.0                   83.0
# 4022                34.0               116.0                   81.0
# 4023                35.0               139.0                   94.0
# 4024                44.0               179.0                  108.0
# 4025                41.0               170.0                  109.0
# 4026                32.0               145.0                   88.0
# 4027                29.0               118.0                   75.0
# 4028                47.0               203.0                  123.0
# 4029                29.0               111.0                   72.0
# 4030                34.0               112.0                   83.0
# 4031                40.0               172.0                  111.0
#
#      pitch_strikes_contacted pitch_strikes_swinging pitch_strikes_looking  \
# 0                       55.0                   15.0                  23.0
# 1                       58.0                   20.0                  14.0
# 2                        NaN                    NaN                   NaN
# 3                       48.0                   21.0                  14.0
# 4                       42.0                   23.0                  13.0
# 5                       56.0                    9.0                  24.0
# 6                       41.0                   13.0                  17.0
# 7                        NaN                    NaN                   NaN
# 8                       58.0                   10.0                  17.0
# 9                       47.0                   11.0                  14.0
# 10                      51.0                   13.0                  22.0
# 11                      41.0                   17.0                  20.0
# 12                      41.0                   16.0                  20.0
# 13                      51.0                    9.0                  22.0
# 14                      55.0                   10.0                  23.0
# 15                      60.0                    7.0                  30.0
# 16                      48.0                   11.0                  29.0
# 17                      31.0                   17.0                  12.0
# 18                      51.0                    9.0                  16.0
# 19                      56.0                   20.0                  17.0
# 20                       NaN                    NaN                   NaN
# 21                       NaN                    NaN                   NaN
# 22                      48.0                   13.0                  16.0
# 23                      48.0                   15.0                  30.0
# 24                      49.0                    7.0                  28.0
# 25                      46.0                   18.0                  19.0
# 26                      57.0                   16.0                  23.0
# 27                      37.0                   18.0                  30.0
# 28                      49.0                    9.0                  27.0
# 29                      76.0                   19.0                  23.0
# ...                      ...                    ...                   ...
# 4002                    53.0                   16.0                  24.0
# 4003                    49.0                   30.0                  26.0
# 4004                    51.0                   21.0                  34.0
# 4005                    63.0                   15.0                  34.0
# 4006                    41.0                   19.0                  26.0
# 4007                    38.0                   22.0                  19.0
# 4008                    45.0                   44.0                  22.0
# 4009                    51.0                   14.0                  21.0
# 4010                    98.0                   20.0                  36.0
# 4011                    52.0                   20.0                  23.0
# 4012                    49.0                   21.0                  24.0
# 4013                    20.0                   24.0                  31.0
# 4014                    40.0                   20.0                  19.0
# 4015                    84.0                   18.0                  32.0
# 4016                    50.0                   22.0                  34.0
# 4017                    47.0                   28.0                  23.0
# 4018                    32.0                   20.0                  28.0
# 4019                    41.0                   27.0                  28.0
# 4020                    63.0                   12.0                  20.0
# 4021                    35.0                   19.0                  29.0
# 4022                    42.0                   19.0                  20.0
# 4023                    57.0                   14.0                  23.0
# 4024                    52.0                   24.0                  32.0
# 4025                    61.0                   26.0                  22.0
# 4026                    38.0                   25.0                  25.0
# 4027                    35.0                   18.0                  22.0
# 4028                    70.0                   18.0                  35.0
# 4029                    36.0                   19.0                  17.0
# 4030                    38.0                   20.0                  25.0
# 4031                    53.0                   27.0                  31.0
#
#      pitch_wpa
# 0        0.270
# 1       -0.325
# 2        0.137
# 3        0.156
# 4        0.367
# 5        0.349
# 6        0.269
# 7        0.054
# 8        0.148
# 9       -0.274
# 10      -0.350
# 11       0.233
# 12       0.006
# 13       0.033
# 14      -0.222
# 15      -0.406
# 16      -0.169
# 17       0.314
# 18       0.190
# 19      -0.346
# 20       0.229
# 21       0.637
# 22       0.282
# 23       0.036
# 24      -0.508
# 25      -0.082
# 26      -0.391
# 27       0.394
# 28       0.009
# 29      -0.411
# ...        ...
# 4002     0.244
# 4003     0.037
# 4004    -0.737
# 4005     0.202
# 4006    -0.276
# 4007     0.666
# 4008     0.452
# 4009    -0.142
# 4010    -0.031
# 4011     0.110
# 4012     0.623
# 4013     0.149
# 4014     0.082
# 4015    -0.486
# 4016    -0.188
# 4017     0.118
# 4018     0.394
# 4019     0.424
# 4020     0.137
# 4021     0.465
# 4022     0.531
# 4023     0.318
# 4024    -0.271
# 4025     0.099
# 4026     0.538
# 4027     0.581
# 4028     0.308
# 4029     0.566
# 4030     0.160
# 4031     0.158
#
# [4032 rows x 41 columns] done.
# CPU times: user 17.7 s, sys: 142 ms, total: 17.8 s
# Wall time: 29.4 s

# %%
arizona = pd.read_csv('../data/pre_clean_data/ARI/arizona_pc.csv')

# %%
atlanta = pd.read_csv('../data/pre_clean_data/ATL/atlanta_pc.csv')

# %%
season_cleaner(atlanta)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# atlanta
# all seasons for atlanta done.

# %%
baltimore = pd.read_csv('../data/pre_clean_data/BAL/baltimore_pc.csv')

# %%
season_cleaner(baltimore)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# baltimore
# all seasons for baltimore done.

# %%
boston = pd.read_csv('../data/pre_clean_data/BOS/boston_pc.csv')

# %%
season_cleaner(boston)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# boston
# all seasons for boston done.

# %%
cubs = pd.read_csv('../data/pre_clean_data/CHC/cubs_pc.csv')

# %%
season_cleaner(cubs)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# cubs
# all seasons for cubs done.

# %%
white_sox = pd.read_csv('../data/pre_clean_data/CHW/chicago_white_sox_pc.csv')

# %%
season_cleaner(white_sox)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# white_sox
# all seasons for white_sox done.

# %%
reds = pd.read_csv('../data/pre_clean_data/CIN/reds_pc.csv')

# %%
season_cleaner(reds)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# reds
# all seasons for reds done.

# %%
indians = pd.read_csv('../data/pre_clean_data/CLE/cleveland_pc.csv')

# %%
season_cleaner(indians)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# cleveland
# all seasons for cleveland done.

# %%
rockies = pd.read_csv('../data/pre_clean_data/COL/colorado_pc.csv')

# %%
season_cleaner(rockies)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# colorado
# all seasons for colorado done.

# %%
detroit = pd.read_csv('../data/pre_clean_data/DET/detroit_pc.csv')

# %%
season_cleaner(detroit)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# detroit
# all seasons for detroit done.

# %%
royals = pd.read_csv('../data/pre_clean_data/KCR/kansas_city_pc.csv')

# %%
season_cleaner(royals)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# kansas_city
# all seasons for kansas_city done.

# %%
angels = pd.read_csv('../data/pre_clean_data/LAA/angels_pc.csv')

# %%
season_cleaner(angels)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# angels
# all seasons for angels done.

# %%
dodgers = pd.read_csv('../data/pre_clean_data/LAD/dodgers_pc.csv')

# %%
season_cleaner(dodgers)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# dodgers
# all seasons for dodgers done.

# %%
miami = pd.read_csv('../data/pre_clean_data/MIA/marlins_pc.csv')

# %%
season_cleaner(miami)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# miami
# all seasons for miami done.

# %%
brewers = pd.read_csv('../data/pre_clean_data/MIL/brewers_pc.csv')

# %%
season_cleaner(brewers)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# brewers
# all seasons for brewers done.

# %%
minnesota = pd.read_csv('../data/pre_clean_data/MIN/minnesota_pc.csv')

# %%
season_cleaner(minnesota)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# minnesota
# all seasons for minnesota done.

# %%
mets = pd.read_csv('../data/pre_clean_data/NYM/mets_pc.csv')

# %%
season_cleaner(mets)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# mets
# all seasons for mets done.

# %%
yankees = pd.read_csv('../data/pre_clean_data/NYY/new_york_pc.csv')

# %%
season_cleaner(yankees)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# yankees
# all seasons for yankees done.

# %%
oakland = pd.read_csv('../data/pre_clean_data/OAK/oakland_pc.csv')

# %%
season_cleaner(oakland)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# oakland
# all seasons for oakland done.

# %%
phillies = pd.read_csv('../data/pre_clean_data/PHI/philadelphia_pc.csv')

# %%
season_cleaner(phillies)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# phillies
# all seasons for phillies done.

# %%
pirates = pd.read_csv('../data/pre_clean_data/PIT/pirates_pc.csv')

# %%
season_cleaner(pirates)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# pirates
# all seasons for pirates done.

# %%
padres = pd.read_csv('../data/pre_clean_data/SDP/san_diego_pc.csv')

# %%
season_cleaner(padres)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# padres
# all seasons for padres done.

# %%
seattle = pd.read_csv('../data/pre_clean_data/SEA/seattle_pc.csv')

# %%
season_cleaner(seattle)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# seattle
# all seasons for seattle done.

# %%
giants = pd.read_csv('../data/pre_clean_data/SFG/san_francisco_pc.csv')

# %%
season_cleaner(giants)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# giants
# all seasons for giants done.

# %%
cardinals = pd.read_csv('../data/pre_clean_data/STL/cardinals_pc.csv')

# %%
season_cleaner(cardinals)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# cardinals
# all seasons for cardinals done.

# %%
rangers = pd.read_csv('../data/pre_clean_data/TEX/rangers_pc.csv')

# %%
season_cleaner(rangers)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# rangers
# all seasons for rangers done.

# %%
toronto = pd.read_csv('../data/pre_clean_data/TOR/toronto_pc.csv')

# %%
season_cleaner(toronto)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# toronto
# all seasons for toronto done.

# %%
nationals = pd.read_csv('../data/pre_clean_data/WSN/washington_pc.csv')

# %%
season_cleaner(nationals)
# Out:
# 1995 done
# 1996 done
# 1997 done
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# nationals
# all seasons for nationals done.

# %%
def season_cleaner_2(team_df):
    season_list = [1998, 1999,
                   2000, 2001, 2002, 2003, 2004, 
                   2005, 2006, 2007, 2008, 2009,
                   2010, 2011, 2012, 2013, 2014,
                   2015, 2016, 2017, 2018, 2019]
    team_seasons = []
    for season in season_list:
        #converts date column to datetimeobject
        team_df['date'] = pd.to_datetime(team_df['date'])
        df = team_df[team_df['date'].dt.year == season].copy()
        #datetime setup
        df['year'] = df['date'].dt.year
        df['month'] = df['date'].dt.month
        df['day'] = df['date'].dt.day
        df['weekday'] = df['date'].dt.weekday
        df['weekday_name'] = df['date'].dt.weekday_name
        wins = []
        losses = []
        for wl in df['record']:
            w, l = wl.split('-')
            wins.append(int(w))
            losses.append(int(l))
        df['wins'] = wins
        df['losses'] = losses
        df['total_games'] = df['wins'] + df['losses']
        df['win_pct'] = df['wins'] / df['total_games']
        #drop attendance nan value rows
        df.dropna(subset=['attendance'], inplace=True)
        #attendance convert from string to int
        df['attendance'] = df['attendance'].str.replace(',', '').astype(int)
        ### streak convert ####
        df['streak'].fillna('0', inplace=True)
        df['streak'] = [len(x) if '+' in x else -len(x) if '-' in x else 0 for x in df['streak']]
        #games back convert
        df['games_back'] = [0. if x == ' Tied' or x == '0'else float(x.replace('up', '')) if 'up' in x else -float(x) for x in df['games_back']]
        # average runs per game feature
        df['runs_pg_avg'] = [0 if x == min(df['date']) else df[df['date'] < x].r.astype(int).mean() for x in df['date']]
        #5 game moving runs average 
        df['runs_mavg_5'] = df['r'].rolling(5).mean().shift()
        # 5 game moving runs against average
        df['runs_against_mavg_5'] = df['ra'].rolling(5).mean().shift()
        #ten game moving win percentage
        ten_game_win_perc = [list(df['win_loss'][i-10:i]).count('W') / 10. for i in range(10, len(df))]
        for i in range(10):
            ten_game_win_perc.insert(0, None)
        df['ten_game_win_perc'] = ten_game_win_perc
        # 5 game era moving average
        df['era_mavg_5'] = df['pitch_era'].rolling(5).mean().shift()
        # 5 game batting average moving average
        df['bat_avg_mavg_5'] = df['bat_batting_avg'].rolling(5).mean().shift()
        # 5 game bat ops moving average
        df['ops_mavg_5'] = df['bat_ops'].rolling(5).mean().shift()
        # average hits per game
        df['hits_pg_avg'] = [0 if x == min(df['date']) else df[df['date'] < x].bat_hits.mean() for x in df['date']]
        # 5 game hits moving average
        df['hits_mavg_5'] = df['bat_hits'].rolling(5).mean().shift()
        # batting strike outs per game
        df['bat_stkout_pg_avg'] = [0 if x == min(df['date']) else df[df['date'] < x].bat_strike_outs.mean() for x in df['date']]
        # pitching strikeout per game
        df['ptich_stkout_pg_avg'] = [0 if x == min(df['date']) else df[df['date'] < x].pitch_strike_outs.mean() for x in df['date']]
        # 5 game pitching strikeout moving average
        df['pitch_strkout_mavg_5'] = df['pitch_strike_outs'].rolling(5).mean().shift()
        # opening day dummy
        df['opening_day'] = [1 if x == min(df['date']) else 0 for x in df['date']]
        #night game dummy
        df['night_game'] = [1 if x == 'N' else 0 for x in df['day_night']]
        #fill nan values created by the rolling means with values from the same column
        df['runs_mavg_5'] = [df.iloc[i].r if np.isnan(j) else j for i, j in enumerate(df['runs_mavg_5'])]
        df['runs_against_mavg_5'] = [df.iloc[i].ra if np.isnan(j) else j for i, j in enumerate(df['runs_against_mavg_5'])]
        df['ten_game_win_perc'] = [df.iloc[i].win_pct if np.isnan(j) else j for i, j in enumerate(df['ten_game_win_perc'])]
        df['era_mavg_5'] = [df.iloc[i].pitch_era if np.isnan(j) else j for i, j in enumerate(df['era_mavg_5'])]
        df['bat_avg_mavg_5'] = [df.iloc[i].bat_batting_avg if np.isnan(j) else j for i, j in enumerate(df['bat_avg_mavg_5'])]
        df['ops_mavg_5'] = [df.iloc[i].bat_ops if np.isnan(j) else j for i, j in enumerate(df['ops_mavg_5'])]
        df['hits_mavg_5'] = [df.iloc[i].bat_hits if np.isnan(j) else j for i, j in enumerate(df['hits_mavg_5'])]
        df['pitch_strkout_mavg_5'] = [df.iloc[i].pitch_strike_outs if np.isnan(j) else j for i, j in enumerate(df['pitch_strkout_mavg_5'])]
        #drop all away games from season data
        df['home_away'].fillna('home',inplace=True)
        df = df[~df['home_away'].str.contains('@')].reset_index(drop=True)

        team_seasons.append(df)
        print(f'{season} done')
    club = pd.concat(team_seasons)
    print('name for file:')
    a = input()
    club.to_csv(f'../data/clean_data/{a}_clean.csv', index=False)
        
    return print(f'all seasons for {a} done.')

# %%
season_cleaner_2(arizona)
# Out:
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# arizona
# all seasons for arizona done.

# %%
rays = pd.read_csv('../data/pre_clean_data/TBR/tampa_bay_pc.csv')

# %%
season_cleaner_2(rays)
# Out:
# 1998 done
# 1999 done
# 2000 done
# 2001 done
# 2002 done
# 2003 done
# 2004 done
# 2005 done
# 2006 done
# 2007 done
# 2008 done
# 2009 done
# 2010 done
# 2011 done
# 2012 done
# 2013 done
# 2014 done
# 2015 done
# 2016 done
# 2017 done
# 2018 done
# 2019 done
# name for file:
# tampa_bay
# all seasons for tampa_bay done.

# %%
HOU = pd.read_csv('../data/clean_data/houston_clean.csv')
TEX = pd.read_csv('../data/clean_data/rangers_clean.csv')
SEA = pd.read_csv('../data/clean_data/seattle_clean.csv')
OAK = pd.read_csv('../data/clean_data/oakland_clean.csv')
LAA = pd.read_csv('../data/clean_data/angels_clean.csv')
NYY = pd.read_csv('../data/clean_data/yankees_clean.csv')
BOS = pd.read_csv('../data/clean_data/boston_clean.csv')
TOR = pd.read_csv('../data/clean_data/toronto_clean.csv')
BAL = pd.read_csv('../data/clean_data/baltimore_clean.csv')
TBR = pd.read_csv('../data/clean_data/tampa_bay_clean.csv')
MIN = pd.read_csv('../data/clean_data/minnesota_clean.csv')
CLE = pd.read_csv('../data/clean_data/cleveland_clean.csv')
CHW = pd.read_csv('../data/clean_data/white_sox_clean.csv')
KCR = pd.read_csv('../data/clean_data/kansas_city_clean.csv')
DET = pd.read_csv('../data/clean_data/detroit_clean.csv')
LAD = pd.read_csv('../data/clean_data/dodgers_clean.csv')
SFG = pd.read_csv('../data/clean_data/giants_clean.csv')
COL = pd.read_csv('../data/clean_data/colorado_clean.csv')
SDP = pd.read_csv('../data/clean_data/padres_clean.csv')
ARI = pd.read_csv('../data/clean_data/arizona_clean.csv')
ATL = pd.read_csv('../data/clean_data/atlanta_clean.csv')
NYM = pd.read_csv('../data/clean_data/mets_clean.csv')
PHI = pd.read_csv('../data/clean_data/phillies_clean.csv')
WSN = pd.read_csv('../data/clean_data/nationals_clean.csv')
MIA = pd.read_csv('../data/clean_data/miami_clean.csv')
STL = pd.read_csv('../data/clean_data/cardinals_clean.csv')
MIL = pd.read_csv('../data/clean_data/brewers_clean.csv')
CHC = pd.read_csv('../data/clean_data/cubs_clean.csv')
CIN = pd.read_csv('../data/clean_data/reds_clean.csv')
PIT = pd.read_csv('../data/clean_data/pirates_clean.csv')

# %%
mlb_df = pd.concat([HOU, TEX, SEA, OAK, LAA, NYY, BOS, TOR, BAL, TBR, 
                    MIN, CLE, CHW, KCR, DET, LAD, SFG, COL, SDP, ARI, 
                    ATL, NYM, PHI, WSN, MIA, STL, MIL, CHC, CIN, PIT], sort = False)

# %%
mlb_df.to_csv('../data/clean_data/mlb_df.csv', index=False)

# %%
HOU = pd.read_csv('../data/stadiums/HOU_stadium_data.csv')
TEX = pd.read_csv('../data/stadiums/TEX_stadium_data.csv')
SEA = pd.read_csv('../data/stadiums/SEA_stadium_data.csv')
OAK = pd.read_csv('../data/stadiums/OAK_stadium_data.csv')
LAA = pd.read_csv('../data/stadiums/LAA_stadium_data.csv')
NYY = pd.read_csv('../data/stadiums/NYY_stadium_data.csv')
BOS = pd.read_csv('../data/stadiums/BOS_stadium_data.csv')
TOR = pd.read_csv('../data/stadiums/TOR_stadium_data.csv')
BAL = pd.read_csv('../data/stadiums/BAL_stadium_data.csv')
TBR = pd.read_csv('../data/stadiums/TBR_stadium_data.csv')
MIN = pd.read_csv('../data/stadiums/MIN_stadium_data.csv')
CLE = pd.read_csv('../data/stadiums/CLE_stadium_data.csv')
CHW = pd.read_csv('../data/stadiums/CHW_stadium_data.csv')
KCR = pd.read_csv('../data/stadiums/KCR_stadium_data.csv')
DET = pd.read_csv('../data/stadiums/DET_stadium_data.csv')
LAD = pd.read_csv('../data/stadiums/LAD_stadium_data.csv')
SFG = pd.read_csv('../data/stadiums/SFG_stadium_data.csv')
COL = pd.read_csv('../data/stadiums/COL_stadium_data.csv')
SDP = pd.read_csv('../data/stadiums/SDP_stadium_data.csv')
ARI = pd.read_csv('../data/stadiums/ARI_stadium_data.csv')
ATL = pd.read_csv('../data/stadiums/ATL_stadium_data.csv')
NYM = pd.read_csv('../data/stadiums/NYM_stadium_data.csv')
PHI = pd.read_csv('../data/stadiums/PHI_stadium_data.csv')
WSN = pd.read_csv('../data/stadiums/WSN_stadium_data.csv')
MIA = pd.read_csv('../data/stadiums/MIA_stadium_data.csv')
STL = pd.read_csv('../data/stadiums/STL_stadium_data.csv')
MIL = pd.read_csv('../data/stadiums/MIL_stadium_data.csv')
CHC = pd.read_csv('../data/stadiums/CHC_stadium_data.csv')
CIN = pd.read_csv('../data/stadiums/CIN_stadium_data.csv')
PIT = pd.read_csv('../data/stadiums/Pit_stadium_data.csv')

# %%
mlb_stadiums = pd.concat([HOU, TEX, SEA, OAK, LAA, NYY, BOS, TOR, BAL, TBR, 
                    MIN, CLE, CHW, KCR, DET, LAD, SFG, COL, SDP, ARI, 
                    ATL, NYM, PHI, WSN, MIA, STL, MIL, CHC, CIN, PIT], sort = False)

# %%
mlb_stadiums.to_csv('../data/stadiums/mlb_stadiums.csv', index=False)

# %%
# Out:
# team        object
# year         int64
# state       object
# stadium     object
# capacity     int64
# dtype: object

# %%
HOU = pd.read_csv('../data/franchise/HOU_franchise.csv')
TEX = pd.read_csv('../data/franchise/TEX_franchise.csv')
SEA = pd.read_csv('../data/franchise/SEA_franchise.csv')
OAK = pd.read_csv('../data/franchise/OAK_franchise.csv')
LAA = pd.read_csv('../data/franchise/ANA_franchise.csv')
NYY = pd.read_csv('../data/franchise/NYY_franchise.csv')
BOS = pd.read_csv('../data/franchise/BOS_franchise.csv')
TOR = pd.read_csv('../data/franchise/TOR_franchise.csv')
BAL = pd.read_csv('../data/franchise/BAL_franchise.csv')
TBR = pd.read_csv('../data/franchise/TBD_franchise.csv')
MIN = pd.read_csv('../data/franchise/MIN_franchise.csv')
CLE = pd.read_csv('../data/franchise/CLE_franchise.csv')
CHW = pd.read_csv('../data/franchise/CHW_franchise.csv')
KCR = pd.read_csv('../data/franchise/KCR_franchise.csv')
DET = pd.read_csv('../data/franchise/DET_franchise.csv')
LAD = pd.read_csv('../data/franchise/LAD_franchise.csv')
SFG = pd.read_csv('../data/franchise/SFG_franchise.csv')
COL = pd.read_csv('../data/franchise/COL_franchise.csv')
SDP = pd.read_csv('../data/franchise/SDP_franchise.csv')
ARI = pd.read_csv('../data/franchise/ARI_franchise.csv')
ATL = pd.read_csv('../data/franchise/ATL_franchise.csv')
NYM = pd.read_csv('../data/franchise/NYM_franchise.csv')
PHI = pd.read_csv('../data/franchise/PHI_franchise.csv')
WSN = pd.read_csv('../data/franchise/WSN_franchise.csv')
MIA = pd.read_csv('../data/franchise/FLA_franchise.csv')
STL = pd.read_csv('../data/franchise/STL_franchise.csv')
MIL = pd.read_csv('../data/franchise/MIL_franchise.csv')
CHC = pd.read_csv('../data/franchise/CHC_franchise.csv')
CIN = pd.read_csv('../data/franchise/CIN_franchise.csv')
PIT = pd.read_csv('../data/franchise/PIT_franchise.csv')

# %%
mlb_franchise = pd.concat([HOU, TEX, SEA, OAK, LAA, NYY, BOS, TOR, BAL, TBR, 
                    MIN, CLE, CHW, KCR, DET, LAD, SFG, COL, SDP, ARI, 
                    ATL, NYM, PHI, WSN, MIA, STL, MIL, CHC, CIN, PIT], sort = False)

# %%
mlb_franchise['season_total_attendance'] = mlb_franchise['season_total_attendance'].str.replace(',', '').astype(int)

# %%
mlb_franchise.to_csv('../data/franchise/mlb_franchise.csv', index=False)

# %%
HOU = pd.read_csv('../data/attendance/HOU_attendance.csv')
TEX = pd.read_csv('../data/attendance/TEX_attendance.csv')
SEA = pd.read_csv('../data/attendance/SEA_attendance.csv')
OAK = pd.read_csv('../data/attendance/OAK_attendance.csv')
LAA = pd.read_csv('../data/attendance/ANA_attendance.csv')
NYY = pd.read_csv('../data/attendance/NYY_attendance.csv')
BOS = pd.read_csv('../data/attendance/BOS_attendance.csv')
TOR = pd.read_csv('../data/attendance/TOR_attendance.csv')
BAL = pd.read_csv('../data/attendance/BAL_attendance.csv')
TBR = pd.read_csv('../data/attendance/TBD_attendance.csv')
MIN = pd.read_csv('../data/attendance/MIN_attendance.csv')
CLE = pd.read_csv('../data/attendance/CLE_attendance.csv')
CHW = pd.read_csv('../data/attendance/CHW_attendance.csv')
KCR = pd.read_csv('../data/attendance/KCR_attendance.csv')
DET = pd.read_csv('../data/attendance/DET_attendance.csv')
LAD = pd.read_csv('../data/attendance/LAD_attendance.csv')
SFG = pd.read_csv('../data/attendance/SFG_attendance.csv')
COL = pd.read_csv('../data/attendance/COL_attendance.csv')
SDP = pd.read_csv('../data/attendance/SDP_attendance.csv')
ARI = pd.read_csv('../data/attendance/ARI_attendance.csv')
ATL = pd.read_csv('../data/attendance/ATL_attendance.csv')
NYM = pd.read_csv('../data/attendance/NYM_attendance.csv')
PHI = pd.read_csv('../data/attendance/PHI_attendance.csv')
WSN = pd.read_csv('../data/attendance/WSN_attendance.csv')
MIA = pd.read_csv('../data/attendance/FLA_attendance.csv')
STL = pd.read_csv('../data/attendance/STL_attendance.csv')
MIL = pd.read_csv('../data/attendance/MIL_attendance.csv')
CHC = pd.read_csv('../data/attendance/CHC_attendance.csv')
CIN = pd.read_csv('../data/attendance/CIN_attendance.csv')
PIT = pd.read_csv('../data/attendance/PIT_attendance.csv')

# %%
mlb_attendance = pd.concat([HOU, TEX, SEA, OAK, LAA, NYY, BOS, TOR, BAL, TBR, 
                    MIN, CLE, CHW, KCR, DET, LAD, SFG, COL, SDP, ARI, 
                    ATL, NYM, PHI, WSN, MIA, STL, MIL, CHC, CIN, PIT], sort = False)

# %%
mlb_attendance['est_payroll'] = mlb_attendance['est_payroll'].replace('[\$,]', '', regex=True).astype(float)

# %%
mlb_attendance['attendance_game_avg'] = mlb_attendance['attendance_game_avg'].str.replace(',', '').astype(int)

# %%
mlb_attendance.to_csv('../data/attendance/mlb_attendance.csv', index=False)

# %%
mlb_stadiums.dtypes
# Out:
# team        object
# year         int64
# state       object
# stadium     object
# capacity     int64
# dtype: object

# %%
mlb_df = mlb_df.merge(mlb_stadiums.drop('state', axis = 1), on =['team', 'year'])

# %%
mlb
# Out:
#       game#  day        date team home_away  opp win_loss     r    ra  \
# 0         3   28  1995-04-28  HOU      home  COL        L   1.0   2.0
# 1         4   29  1995-04-29  HOU      home  COL        L   1.0   2.0
# 2         5   30  1995-04-30  HOU      home  COL        W   3.0   1.0
# 3        15   12  1995-05-12  HOU      home  PHI        L   2.0   5.0
# 4        16   13  1995-05-13  HOU      home  PHI        L   5.0   7.0
# 5        17   14  1995-05-14  HOU      home  PHI        L   2.0   5.0
# 6        18   16  1995-05-16  HOU      home  NYM        L   0.0   1.0
# 7        19   17  1995-05-17  HOU      home  NYM        W   7.0   2.0
# 8        20   18  1995-05-18  HOU      home  NYM        L   1.0   8.0
# 9        21   19  1995-05-19  HOU      home  MON        W  10.0   2.0
# 10       22   20  1995-05-20  HOU      home  MON     W-wo   2.0   1.0
# 11       23   21  1995-05-21  HOU      home  MON        W   5.0   2.0
# 12       27   26  1995-05-26  HOU      home  ATL        L   3.0   8.0
# 13       28   27  1995-05-27  HOU      home  ATL     W-wo   3.0   2.0
# 14       29   28  1995-05-28  HOU      home  ATL        L   1.0   3.0
# 15       35    5  1995-06-05  HOU      home  FLA     W-wo   6.0   5.0
# 16       36    6  1995-06-06  HOU      home  FLA        L   6.0   7.0
# 17       37    7  1995-06-07  HOU      home  FLA        L   3.0   8.0
# 18       38    8  1995-06-08  HOU      home  CIN        L   3.0   6.0
# 19       39    9  1995-06-09  HOU      home  CIN        L   2.0   5.0
# 20       40   10  1995-06-10  HOU      home  CIN        L   2.0   3.0
# 21       41   11  1995-06-11  HOU      home  CIN        L   2.0   3.0
# 22       51   22  1995-06-22  HOU      home  CHC        L   2.0  13.0
# 23       52   23  1995-06-23  HOU      home  CHC     W-wo   3.0   2.0
# 24       53   24  1995-06-24  HOU      home  CHC        L   2.0   5.0
# 25       54   25  1995-06-25  HOU      home  CHC        W  19.0   6.0
# 26       55   26  1995-06-26  HOU      home  STL        W  11.0   0.0
# 27       56   27  1995-06-27  HOU      home  STL        W   6.0   2.0
# 28       57   28  1995-06-28  HOU      home  STL        W   9.0   0.0
# 29       58   30  1995-06-30  HOU      home  PIT        L   9.0  12.0
# ...     ...  ...         ...  ...       ...  ...      ...   ...   ...
# 1983    103   23  2019-07-23  HOU      home  OAK        L   3.0   4.0
# 1984    104   24  2019-07-24  HOU      home  OAK        W   4.0   2.0
# 1985    111    2  2019-08-02  HOU      home  SEA        W  10.0   2.0
# 1986    112    3  2019-08-03  HOU      home  SEA        W   9.0   0.0
# 1987    113    4  2019-08-04  HOU      home  SEA        W   3.0   1.0
# 1988    114    6  2019-08-06  HOU      home  COL        W  11.0   6.0
# 1989    115    7  2019-08-07  HOU      home  COL        W  14.0   3.0
# 1990    126   19  2019-08-19  HOU      home  DET        W   5.0   4.0
# 1991    127   20  2019-08-20  HOU      home  DET        W   6.0   3.0
# 1992    128   21  2019-08-21  HOU      home  DET        L   1.0   2.0
# 1993    129   22  2019-08-22  HOU      home  DET        W   6.0   3.0
# 1994    130   23  2019-08-23  HOU      home  LAA        W   5.0   4.0
# 1995    131   24  2019-08-24  HOU      home  LAA        W   5.0   2.0
# 1996    132   25  2019-08-25  HOU      home  LAA        W  11.0   2.0
# 1997    133   27  2019-08-27  HOU      home  TBR        W  15.0   1.0
# 1998    134   28  2019-08-28  HOU      home  TBR        W   8.0   6.0
# 1999    135   29  2019-08-29  HOU      home  TBR        L   8.0   9.0
# 2000    141    5  2019-09-05  HOU      home  SEA     W-wo  11.0   9.0
# 2001    142    6  2019-09-06  HOU      home  SEA        W   7.0   4.0
# 2002    143    7  2019-09-07  HOU      home  SEA        W   2.0   1.0
# 2003    144    8  2019-09-08  HOU      home  SEA        W  21.0   1.0
# 2004    145    9  2019-09-09  HOU      home  OAK        W  15.0   0.0
# 2005    146   10  2019-09-10  HOU      home  OAK        L   7.0  21.0
# 2006    147   11  2019-09-11  HOU      home  OAK        L   3.0   5.0
# 2007    148   12  2019-09-12  HOU      home  OAK        L   2.0   3.0
# 2008    152   17  2019-09-17  HOU      home  TEX        W   4.0   1.0
# 2009    153   18  2019-09-18  HOU      home  TEX        W   3.0   2.0
# 2010    154   20  2019-09-20  HOU      home  LAA        W   6.0   4.0
# 2011    155   21  2019-09-21  HOU      home  LAA        L   4.0   8.0
# 2012    156   22  2019-09-22  HOU      home  LAA        W  13.0   5.0
#
#       innings  ... ops_mavg_5  hits_pg_avg  hits_mavg_5 bat_stkout_pg_avg  \
# 0         NaN  ...     0.6830     8.500000          7.0          9.500000
# 1         NaN  ...     0.4620     8.000000          4.0          9.000000
# 2         NaN  ...     0.5130     7.000000          5.0          8.750000
# 3         NaN  ...     0.8970     9.928571         12.4          6.642857
# 4         NaN  ...     0.8718     9.800000         12.6          6.733333
# 5         NaN  ...     0.8004     9.625000         11.2          6.625000
# 6         NaN  ...     0.7642     9.352941         10.6          6.588235
# 7         NaN  ...     0.6474     9.000000          8.0          6.611111
# 8         NaN  ...     0.6234     9.263158          7.4          6.631579
# 9         NaN  ...     0.5882     9.100000          7.0          6.500000
# 10       10.0  ...     0.6436     9.095238          7.4          6.476190
# 11        NaN  ...     0.7046     9.090909          8.2          6.500000
# 12        NaN  ...     0.6614     9.038462          8.8          6.500000
# 13       10.0  ...     0.6136     8.962963          8.4          6.555556
# 14        NaN  ...     0.6062     9.000000          8.8          6.785714
# 15        NaN  ...     0.7484     8.794118          9.2          7.088235
# 16       11.0  ...     0.7506     8.771429          9.2          7.000000
# 17        NaN  ...     0.7854     8.972222         10.4          7.111111
# 18        NaN  ...     0.8070     8.945946         10.4          7.081081
# 19        NaN  ...     0.8014     8.921053         10.6          6.973684
# 20        NaN  ...     0.7166     8.871795          9.4          6.897436
# 21       10.0  ...     0.7046     8.925000         10.0          6.775000
# 22        NaN  ...     0.7914     9.220000         10.2          7.100000
# 23       12.0  ...     0.7130     9.156863          9.4          7.039216
# 24        NaN  ...     0.6808     9.173077          9.6          7.038462
# 25        NaN  ...     0.6386     9.113208          9.2          7.094340
# 26        NaN  ...     0.6942     9.296296         10.2          7.000000
# 27        NaN  ...     0.7796     9.381818         11.0          7.036364
# 28        NaN  ...     0.8260     9.375000         11.6          7.035714
# 29        NaN  ...     0.9028     9.403509         11.8          7.035088
# ...       ...  ...        ...          ...          ...               ...
# 1983     11.0  ...     0.9656     9.313725          9.6          7.098039
# 1984      NaN  ...     0.9094     9.300971          9.6          7.097087
# 1985      NaN  ...     0.8838     9.272727         10.2          7.200000
# 1986      NaN  ...     0.9678     9.297297         10.4          7.171171
# 1987      NaN  ...     0.9586     9.348214         10.8          7.160714
# 1988      NaN  ...     0.9268     9.309735         10.0          7.168142
# 1989      NaN  ...     1.0210     9.342105         11.2          7.157895
# 1990      NaN  ...     0.8292     9.483871         10.2          7.120968
# 1991      NaN  ...     0.7404     9.472000          8.8          7.160000
# 1992      NaN  ...     0.7632     9.460317          9.0          7.158730
# 1993      NaN  ...     0.7788     9.433071          8.4          7.157480
# 1994      NaN  ...     0.7830     9.429688          8.2          7.140625
# 1995      NaN  ...     0.8212     9.457364          8.8          7.139535
# 1996      NaN  ...     0.8754     9.446154          8.8          7.130769
# 1997      NaN  ...     0.8708     9.450382          9.2          7.122137
# 1998      NaN  ...     1.0164     9.515152         11.6          7.121212
# 1999      NaN  ...     1.0254     9.518797         11.8          7.112782
# 2000     13.0  ...     0.6708     9.453237          8.0          7.208633
# 2001      NaN  ...     0.6718     9.464286          7.6          7.235714
# 2002      NaN  ...     0.7076     9.460993          8.2          7.234043
# 2003      NaN  ...     0.7388     9.436620          8.4          7.239437
# 2004      NaN  ...     0.8630     9.524476         10.8          7.244755
# 2005      NaN  ...     1.0512     9.576389         13.0          7.208333
# 2006      NaN  ...     1.0968     9.593103         13.2          7.193103
# 2007      NaN  ...     1.0810     9.582192         13.0          7.198630
# 2008      NaN  ...     0.8280     9.586667          9.4          7.226667
# 2009      NaN  ...     0.8510     9.569536          9.2          7.238411
# 2010      NaN  ...     0.8604     9.546053          9.2          7.230263
# 2011      NaN  ...     0.9102     9.549020          9.8          7.215686
# 2012      NaN  ...     0.8742     9.525974          9.0          7.207792
#
#      ptich_stkout_pg_avg pitch_strkout_mavg_5 opening_day  night_game  \
# 0               8.000000                  6.0           0           1
# 1               7.333333                  8.0           0           1
# 2               7.500000                 12.0           0           0
# 3               7.000000                  6.2           0           1
# 4               6.866667                  6.2           0           1
# 5               6.562500                  5.2           0           0
# 6               6.529412                  4.8           0           1
# 7               6.444444                  4.2           0           1
# 8               6.315789                  4.4           0           1
# 9               6.400000                  5.0           0           1
# 10              6.571429                  6.6           0           1
# 11              6.863636                  8.0           0           0
# 12              6.769231                  7.6           0           1
# 13              6.851852                  6.8           0           1
# 14              7.071429                  8.2           0           0
# 15              7.441176                  9.4           0           1
# 16              7.371429                  8.8           0           1
# 17              7.305556                  8.0           0           0
# 18              7.243243                  7.6           0           1
# 19              7.342105                  7.4           0           1
# 20              7.358974                  6.8           0           1
# 21              7.400000                  7.6           0           0
# 22              7.440000                  6.4           0           1
# 23              7.372549                  5.8           0           1
# 24              7.461538                  7.4           0           1
# 25              7.528302                  8.0           0           0
# 26              7.518519                  8.0           0           1
# 27              7.472727                  7.8           0           1
# 28              7.553571                  9.4           0           0
# 29              7.543860                  8.4           0           1
# ...                  ...                  ...         ...         ...
# 1983           10.147059                 12.2           0           1
# 1984           10.126214                 12.0           0           0
# 1985           10.090909                  9.0           0           1
# 1986           10.090090                  9.2           0           1
# 1987           10.071429                  8.8           0           0
# 1988           10.115044                  8.8           0           1
# 1989           10.061404                  8.4           0           0
# 1990           10.048387                  9.0           0           1
# 1991           10.080000                 10.4           0           1
# 1992           10.087302                 11.4           0           1
# 1993           10.094488                  9.8           0           1
# 1994           10.125000                 11.4           0           1
# 1995           10.069767                 10.6           0           1
# 1996           10.053846                  9.4           0           0
# 1997           10.038168                  8.8           0           1
# 1998           10.000000                  7.6           0           1
# 1999           10.067669                  8.6           0           0
# 2000           10.115108                 11.2           0           1
# 2001           10.150000                 12.2           0           1
# 2002           10.156028                 13.0           0           1
# 2003           10.154930                 12.2           0           0
# 2004           10.202797                 11.6           0           1
# 2005           10.201389                 12.6           0           1
# 2006           10.179310                 11.0           0           1
# 2007           10.219178                 12.0           0           1
# 2008           10.253333                 12.4           0           1
# 2009           10.264901                 11.6           0           1
# 2010           10.269737                 10.4           0           1
# 2011           10.274510                 10.2           0           1
# 2012           10.272727                 10.2           0           0
#
#                stadium capacity
# 0            Astrodome    54370
# 1            Astrodome    54370
# 2            Astrodome    54370
# 3            Astrodome    54370
# 4            Astrodome    54370
# 5            Astrodome    54370
# 6            Astrodome    54370
# 7            Astrodome    54370
# 8            Astrodome    54370
# 9            Astrodome    54370
# 10           Astrodome    54370
# 11           Astrodome    54370
# 12           Astrodome    54370
# 13           Astrodome    54370
# 14           Astrodome    54370
# 15           Astrodome    54370
# 16           Astrodome    54370
# 17           Astrodome    54370
# 18           Astrodome    54370
# 19           Astrodome    54370
# 20           Astrodome    54370
# 21           Astrodome    54370
# 22           Astrodome    54370
# 23           Astrodome    54370
# 24           Astrodome    54370
# 25           Astrodome    54370
# 26           Astrodome    54370
# 27           Astrodome    54370
# 28           Astrodome    54370
# 29           Astrodome    54370
# ...                ...      ...
# 1983  Minute Maid Park    41168
# 1984  Minute Maid Park    41168
# 1985  Minute Maid Park    41168
# 1986  Minute Maid Park    41168
# 1987  Minute Maid Park    41168
# 1988  Minute Maid Park    41168
# 1989  Minute Maid Park    41168
# 1990  Minute Maid Park    41168
# 1991  Minute Maid Park    41168
# 1992  Minute Maid Park    41168
# 1993  Minute Maid Park    41168
# 1994  Minute Maid Park    41168
# 1995  Minute Maid Park    41168
# 1996  Minute Maid Park    41168
# 1997  Minute Maid Park    41168
# 1998  Minute Maid Park    41168
# 1999  Minute Maid Park    41168
# 2000  Minute Maid Park    41168
# 2001  Minute Maid Park    41168
# 2002  Minute Maid Park    41168
# 2003  Minute Maid Park    41168
# 2004  Minute Maid Park    41168
# 2005  Minute Maid Park    41168
# 2006  Minute Maid Park    41168
# 2007  Minute Maid Park    41168
# 2008  Minute Maid Park    41168
# 2009  Minute Maid Park    41168
# 2010  Minute Maid Park    41168
# 2011  Minute Maid Park    41168
# 2012  Minute Maid Park    41168
#
# [2013 rows x 65 columns]

# %%
mlb_franchise
# Out:
#     year           team_name      league  total_games  wins  losses  ties  \
# 0   2019      Houston Astros     AL West          162   107      55     0
# 1   2018      Houston Astros     AL West          162   103      59     0
# 2   2017      Houston Astros     AL West          162   101      61     0
# 3   2016      Houston Astros     AL West          162    84      78     0
# 4   2015      Houston Astros     AL West          162    86      76     0
# 5   2014      Houston Astros     AL West          162    70      92     0
# 6   2013      Houston Astros     AL West          162    51     111     0
# 7   2012      Houston Astros  NL Central          162    55     107     0
# 8   2011      Houston Astros  NL Central          162    56     106     0
# 9   2010      Houston Astros  NL Central          162    76      86     0
# 10  2009      Houston Astros  NL Central          162    74      88     0
# 11  2008      Houston Astros  NL Central          161    86      75     0
# 12  2007      Houston Astros  NL Central          162    73      89     0
# 13  2006      Houston Astros  NL Central          162    82      80     0
# 14  2005      Houston Astros  NL Central          163    89      73     1
# 15  2004      Houston Astros  NL Central          162    92      70     0
# 16  2003      Houston Astros  NL Central          162    87      75     0
# 17  2002      Houston Astros  NL Central          162    84      78     0
# 18  2001      Houston Astros  NL Central          162    93      69     0
# 19  2000      Houston Astros  NL Central          162    72      90     0
# 20  1999      Houston Astros  NL Central          162    97      65     0
# 21  1998      Houston Astros  NL Central          162   102      60     0
# 22  1997      Houston Astros  NL Central          162    84      78     0
# 23  1996      Houston Astros  NL Central          162    82      80     0
# 24  1995      Houston Astros  NL Central          144    76      68     0
# 0   2019       Texas Rangers     AL West          162    78      84     0
# 1   2018       Texas Rangers     AL West          162    67      95     0
# 2   2017       Texas Rangers     AL West          162    78      84     0
# 3   2016       Texas Rangers     AL West          162    95      67     0
# 4   2015       Texas Rangers     AL West          162    88      74     0
# ..   ...                 ...         ...          ...   ...     ...   ...
# 20  1999     Cincinnati Reds  NL Central          163    96      67     0
# 21  1998     Cincinnati Reds  NL Central          162    77      85     0
# 22  1997     Cincinnati Reds  NL Central          162    76      86     0
# 23  1996     Cincinnati Reds  NL Central          162    81      81     0
# 24  1995     Cincinnati Reds  NL Central          144    85      59     0
# 0   2019  Pittsburgh Pirates  NL Central          162    69      93     0
# 1   2018  Pittsburgh Pirates  NL Central          161    82      79     0
# 2   2017  Pittsburgh Pirates  NL Central          162    75      87     0
# 3   2016  Pittsburgh Pirates  NL Central          162    78      83     1
# 4   2015  Pittsburgh Pirates  NL Central          162    98      64     0
# 5   2014  Pittsburgh Pirates  NL Central          162    88      74     0
# 6   2013  Pittsburgh Pirates  NL Central          162    94      68     0
# 7   2012  Pittsburgh Pirates  NL Central          162    79      83     0
# 8   2011  Pittsburgh Pirates  NL Central          162    72      90     0
# 9   2010  Pittsburgh Pirates  NL Central          162    57     105     0
# 10  2009  Pittsburgh Pirates  NL Central          161    62      99     0
# 11  2008  Pittsburgh Pirates  NL Central          162    67      95     0
# 12  2007  Pittsburgh Pirates  NL Central          162    68      94     0
# 13  2006  Pittsburgh Pirates  NL Central          162    67      95     0
# 14  2005  Pittsburgh Pirates  NL Central          162    67      95     0
# 15  2004  Pittsburgh Pirates  NL Central          161    72      89     0
# 16  2003  Pittsburgh Pirates  NL Central          162    75      87     0
# 17  2002  Pittsburgh Pirates  NL Central          161    72      89     0
# 18  2001  Pittsburgh Pirates  NL Central          162    62     100     0
# 19  2000  Pittsburgh Pirates  NL Central          162    69      93     0
# 20  1999  Pittsburgh Pirates  NL Central          161    78      83     0
# 21  1998  Pittsburgh Pirates  NL Central          163    69      93     1
# 22  1997  Pittsburgh Pirates  NL Central          162    79      83     0
# 23  1996  Pittsburgh Pirates  NL Central          162    73      89     0
# 24  1995  Pittsburgh Pirates  NL Central          144    58      86     0
#
#     season_win_loss_%  pythagorean_win_loss_% division_finish  \
# 0               0.660                   0.660        1st of 5
# 1               0.636                   0.675        1st of 5
# 2               0.623                   0.611        1st of 5
# 3               0.519                   0.515        3rd of 5
# 4               0.531                   0.575        2nd of 5
# 5               0.432                   0.437        4th of 5
# 6               0.315                   0.354        5th of 5
# 7               0.340                   0.362        6th of 6
# 8               0.346                   0.384        6th of 6
# 9               0.469                   0.420        4th of 6
# 10              0.457                   0.418        5th of 6
# 11              0.534                   0.481        3rd of 6
# 12              0.451                   0.447        4th of 6
# 13              0.506                   0.510        2nd of 6
# 14              0.549                   0.559        2nd of 6
# 15              0.568                   0.564        2nd of 6
# 16              0.537                   0.579        2nd of 6
# 17              0.519                   0.534        2nd of 6
# 18              0.574                   0.544        1st of 6
# 19              0.444                   0.497        4th of 6
# 20              0.599                   0.590        1st of 6
# 21              0.630                   0.652        1st of 6
# 22              0.519                   0.574        1st of 5
# 23              0.506                   0.477        2nd of 5
# 24              0.528                   0.547        2nd of 5
# 0               0.481                   0.463        3rd of 5
# 1               0.414                   0.436        5th of 5
# 2               0.481                   0.490        3rd of 5
# 3               0.586                   0.505        1st of 5
# 4               0.543                   0.511        1st of 5
# ..                ...                     ...             ...
# 20              0.589                   0.589        2nd of 6
# 21              0.475                   0.494        4th of 6
# 22              0.469                   0.427        3rd of 5
# 23              0.500                   0.503        3rd of 5
# 24              0.590                   0.582        1st of 5
# 0               0.426                   0.417        5th of 5
# 1               0.509                   0.499        4th of 5
# 2               0.463                   0.459        4th of 5
# 3               0.484                   0.482        3rd of 5
# 4               0.605                   0.571        2nd of 5
# 5               0.543                   0.535        2nd of 5
# 6               0.580                   0.543        2nd of 5
# 7               0.488                   0.484        4th of 6
# 8               0.444                   0.430        4th of 6
# 9               0.352                   0.329        6th of 6
# 10              0.385                   0.415        6th of 6
# 11              0.414                   0.416        6th of 6
# 12              0.420                   0.429        6th of 6
# 13              0.414                   0.435        5th of 6
# 14              0.414                   0.444        6th of 6
# 15              0.447                   0.459        5th of 6
# 16              0.463                   0.472        4th of 6
# 17              0.447                   0.441        4th of 6
# 18              0.383                   0.380        6th of 6
# 19              0.426                   0.448        5th of 6
# 20              0.484                   0.496        3rd of 6
# 21              0.426                   0.455        6th of 6
# 22              0.488                   0.478        2nd of 5
# 23              0.451                   0.468        5th of 5
# 24              0.403                   0.429        5th of 5
#
#    division_game_back  runs_for  runs_against  season_total_attendance  \
# 0                  --       920           640                  2857367
# 1                  --       797           534                  2980549
# 2                  --       896           700                  2403671
# 3                11.0       724           701                  2306623
# 4                 2.0       729           618                  2153585
# 5                28.0       629           723                  1751829
# 6                45.0       610           848                  1651883
# 7                42.0       583           794                  1607733
# 8                40.0       615           796                  2067016
# 9                15.0       611           729                  2331490
# 10               17.0       643           770                  2521076
# 11               11.0       712           743                  2779487
# 12               12.0       723           813                  3020405
# 13                1.5       735           719                  3022763
# 14               11.0       693           609                  2804760
# 15               13.0       803           698                  3087872
# 16                1.0       805           677                  2454241
# 17               13.0       749           695                  2517357
# 18                 --       847           769                  2904277
# 19               23.0       938           944                  3056139
# 20                 --       823           675                  2706017
# 21                 --       874           620                  2458451
# 22                 --       777           660                  2046781
# 23                6.0       753           792                  1975888
# 24                9.0       747           674                  1363801
# 0                29.0       810           878                  2132994
# 1                36.0       737           848                  2107107
# 2                23.0       799           816                  2507760
# 3                  --       765           757                  2710402
# 4                  --       751           733                  2491875
# ..                ...       ...           ...                      ...
# 20                1.5       865           711                  2061222
# 21               25.0       750           760                  1793649
# 22                8.0       651           764                  1785788
# 23                7.0       778           773                  1861428
# 24                 --       747           623                  1837649
# 0                  22       758           911                  1491439
# 1                  13       692           693                  1465316
# 2                  17       668           731                  1919447
# 3                  25       729           758                  2249201
# 4                   2       697           596                  2498596
# 5                   2       682           631                  2442564
# 6                   3       634           577                  2256862
# 7                  18       651           674                  2091918
# 8                  24       610           712                  1940429
# 9                  34       587           866                  1613399
# 10               28.5       636           768                  1577853
# 11               30.5       735           884                  1609076
# 12                 17       724           846                  1749142
# 13               16.5       691           797                  1861549
# 14                 33       680           769                  1817245
# 15               32.5       680           744                  1580031
# 16                 13       753           801                  1636751
# 17               24.5       641           730                  1784988
# 18                 31       657           858                  2464870
# 19                 26       793           888                  1748908
# 20               18.5       775           782                  1638023
# 21                 33       650           718                  1560950
# 22                  5       725           760                  1657022
# 23                 15       776           833                  1332150
# 24                 27       629           736                   905517
#
#     average_batter_age  average_pitcher_age  number_of_batters  \
# 0                 28.9                 29.9                 45
# 1                 28.1                 30.0                 41
# 2                 28.8                 28.5                 46
# 3                 26.4                 28.9                 43
# 4                 26.3                 29.4                 46
# 5                 25.4                 27.9                 48
# 6                 25.9                 27.2                 50
# 7                 26.6                 27.2                 50
# 8                 28.2                 27.2                 47
# 9                 29.5                 29.6                 48
# 10                31.6                 31.2                 42
# 11                31.1                 30.9                 41
# 12                31.4                 30.2                 41
# 13                30.5                 29.8                 39
# 14                30.3                 30.3                 36
# 15                31.7                 29.6                 42
# 16                31.1                 27.6                 44
# 17                30.1                 27.3                 41
# 18                30.3                 28.4                 45
# 19                29.1                 28.0                 46
# 20                29.8                 27.4                 38
# 21                29.7                 27.8                 38
# 22                28.8                 27.0                 41
# 23                28.2                 28.5                 43
# 24                28.1                 27.9                 44
# 0                 28.8                 28.3                 53
# 1                 27.4                 30.4                 50
# 2                 28.4                 28.8                 51
# 3                 28.4                 28.8                 52
# 4                 28.7                 28.1                 57
# ..                 ...                  ...                ...
# 20                28.3                 28.0                 35
# 21                27.5                 28.0                 47
# 22                28.2                 29.6                 50
# 23                29.3                 29.2                 48
# 24                28.4                 28.3                 47
# 0                 27.4                 27.2                 54
# 1                 27.8                 26.5                 48
# 2                 28.2                 27.1                 47
# 3                 28.9                 28.6                 55
# 4                 28.2                 29.6                 46
# 5                 27.3                 28.1                 45
# 6                 27.9                 28.7                 49
# 7                 27.6                 30.2                 49
# 8                 27.2                 28.1                 52
# 9                 26.5                 28.6                 52
# 10                27.0                 26.3                 49
# 11                28.4                 26.5                 47
# 12                27.2                 27.1                 46
# 13                27.8                 27.0                 42
# 14                27.4                 28.7                 44
# 15                27.2                 27.7                 43
# 16                29.7                 28.3                 46
# 17                27.9                 28.1                 38
# 18                27.8                 28.1                 49
# 19                28.3                 27.1                 46
# 20                28.3                 26.8                 45
# 21                26.7                 26.5                 38
# 22                26.6                 25.7                 43
# 23                28.8                 27.9                 46
# 24                28.3                 26.4                 40
#
#     number_of_pitchers         top_player  \
# 0                   26    A.Bregman (8.4)
# 1                   22    A.Bregman (6.9)
# 2                   27     J.Altuve (8.1)
# 3                   23     J.Altuve (7.7)
# 4                   24    D.Keuchel (6.7)
# 5                   28     J.Altuve (6.1)
# 6                   26     J.Castro (4.1)
# 7                   26    L.Harrell (3.1)
# 8                   23        C.Lee (3.9)
# 9                   25      M.Bourn (5.5)
# 10                  22      M.Bourn (5.0)
# 11                  20    L.Berkman (6.9)
# 12                  21     R.Oswalt (6.6)
# 13                  19    L.Berkman (6.0)
# 14                  17    R.Clemens (8.2)
# 15                  23    L.Berkman (6.0)
# 16                  23    R.Hidalgo (5.7)
# 17                  21     R.Oswalt (6.9)
# 18                  25    L.Berkman (6.5)
# 19                  23    R.Hidalgo (6.3)
# 20                  15    M.Hampton (7.9)
# 21                  18     C.Biggio (6.5)
# 22                  18     C.Biggio (9.4)
# 23                  22    J.Bagwell (7.5)
# 24                  19     C.Biggio (6.3)
# 0                   36      M.Minor (7.6)
# 1                   32      M.Minor (3.8)
# 2                   31    A.Cashner (4.6)
# 3                   31     A.Beltre (6.5)
# 4                   31     A.Beltre (5.9)
# ..                 ...                ...
# 20                  17    M.Cameron (5.5)
# 21                  24     B.Larkin (5.7)
# 22                  25       J.Shaw (3.6)
# 23                  24     B.Larkin (7.2)
# 24                  24    R.Sanders (6.6)
# 0                   34   B.Reynolds (3.9)
# 1                   24    J.Taillon (4.4)
# 2                   24   J.Harrison (3.4)
# 3                   32      S.Marte (4.9)
# 4                   21      S.Marte (5.3)
# 5                   23  A.McCutchen (6.1)
# 6                   29  A.McCutchen (7.9)
# 7                   25  A.McCutchen (6.9)
# 8                   25  A.McCutchen (5.4)
# 9                   28  A.McCutchen (3.8)
# 10                  26      G.Jones (3.3)
# 11                  26     P.Maholm (3.8)
# 12                  25     J.Wilson (3.6)
# 13                  22    F.Sanchez (4.4)
# 14                  19        J.Bay (5.7)
# 15                  22      O.Perez (5.9)
# 16                  23      K.Wells (5.0)
# 17                  19      B.Giles (5.4)
# 18                  22      B.Giles (5.3)
# 19                  24      B.Giles (6.4)
# 20                  21      B.Giles (6.7)
# 21                  17    J.Kendall (5.6)
# 22                  21    F.Cordova (4.3)
# 23                  25     D.Neagle (6.0)
# 24                  21     D.Neagle (4.5)
#
#                                        manager
# 0                             A.Hinch (107-55)
# 1                             A.Hinch (103-59)
# 2                             A.Hinch (101-61)
# 3                              A.Hinch (84-78)
# 4                              A.Hinch (86-76)
# 5       B.Porter (59-79) and T.Lawless (11-13)
# 6                            B.Porter (51-111)
# 7    B.Mills (39-82) and T.DeFrancesco (16-25)
# 8                             B.Mills (56-106)
# 9                              B.Mills (76-86)
# 10          C.Cooper (70-79) and D.Clark (4-9)
# 11                            C.Cooper (86-75)
# 12       P.Garner (58-73) and C.Cooper (15-16)
# 13                            P.Garner (82-80)
# 14                            P.Garner (89-73)
# 15     J.Williams (44-44) and P.Garner (48-26)
# 16                          J.Williams (87-75)
# 17                          J.Williams (84-78)
# 18                           L.Dierker (93-69)
# 19                           L.Dierker (72-90)
# 20     L.Dierker (84-51) and M.Galante (13-14)
# 21                          L.Dierker (102-60)
# 22                           L.Dierker (84-78)
# 23                           T.Collins (82-80)
# 24                           T.Collins (76-68)
# 0                           C.Woodward (78-84)
# 1     J.Banister (64-88) and D.Wakamatsu (3-7)
# 2                           J.Banister (78-84)
# 3                           J.Banister (95-67)
# 4                           J.Banister (88-74)
# ..                                         ...
# 20                            J.McKeon (96-67)
# 21                            J.McKeon (77-85)
# 22       R.Knight (43-56) and J.McKeon (33-30)
# 23                            R.Knight (81-81)
# 24                           D.Johnson (85-59)
# 0          C.Hurdle (69-92) and T.Prince (0-1)
# 1                             C.Hurdle (82-79)
# 2                             C.Hurdle (75-87)
# 3                             C.Hurdle (78-83)
# 4                             C.Hurdle (98-64)
# 5                             C.Hurdle (88-74)
# 6                             C.Hurdle (94-68)
# 7                             C.Hurdle (79-83)
# 8                             C.Hurdle (72-90)
# 9                           J.Russell (57-105)
# 10                           J.Russell (62-99)
# 11                           J.Russell (67-95)
# 12                             J.Tracy (68-94)
# 13                             J.Tracy (67-95)
# 14  L.McClendon (55-81) and P.Mackanin (12-14)
# 15                         L.McClendon (72-89)
# 16                         L.McClendon (75-87)
# 17                         L.McClendon (72-89)
# 18                        L.McClendon (62-100)
# 19                            G.Lamont (69-93)
# 20                            G.Lamont (78-83)
# 21                            G.Lamont (69-93)
# 22                            G.Lamont (79-83)
# 23                           J.Leyland (73-89)
# 24                           J.Leyland (58-86)
#
# [744 rows x 20 columns]

# %%
#playoff dummy for 0 whem missed playoffs, 1 when made playoffs, 2 when won world series
mlb_attendance['playoffs'] = [0 if str(i) == 'nan' else 2 if 'Won' in str(i) else 1 for i in mlb_attendance['playoffs']]

# %%
mlb_attendance.to_csv('../data/attendance/mlb_attendance.csv', index=False)

# %%
mlb_franchise = pd.read_csv('../data/franchise/mlb_franchise.csv')

# %%
mlb_franchise
# Out:
#      year team      league  total_games  wins  losses  ties  \
# 0    2019  HOU     AL West          162   107      55     0
# 1    2018  HOU     AL West          162   103      59     0
# 2    2017  HOU     AL West          162   101      61     0
# 3    2016  HOU     AL West          162    84      78     0
# 4    2015  HOU     AL West          162    86      76     0
# 5    2014  HOU     AL West          162    70      92     0
# 6    2013  HOU     AL West          162    51     111     0
# 7    2012  HOU  NL Central          162    55     107     0
# 8    2011  HOU  NL Central          162    56     106     0
# 9    2010  HOU  NL Central          162    76      86     0
# 10   2009  HOU  NL Central          162    74      88     0
# 11   2008  HOU  NL Central          161    86      75     0
# 12   2007  HOU  NL Central          162    73      89     0
# 13   2006  HOU  NL Central          162    82      80     0
# 14   2005  HOU  NL Central          163    89      73     1
# 15   2004  HOU  NL Central          162    92      70     0
# 16   2003  HOU  NL Central          162    87      75     0
# 17   2002  HOU  NL Central          162    84      78     0
# 18   2001  HOU  NL Central          162    93      69     0
# 19   2000  HOU  NL Central          162    72      90     0
# 20   1999  HOU  NL Central          162    97      65     0
# 21   1998  HOU  NL Central          162   102      60     0
# 22   1997  HOU  NL Central          162    84      78     0
# 23   1996  HOU  NL Central          162    82      80     0
# 24   1995  HOU  NL Central          144    76      68     0
# 25   2019  TEX     AL West          162    78      84     0
# 26   2018  TEX     AL West          162    67      95     0
# 27   2017  TEX     AL West          162    78      84     0
# 28   2016  TEX     AL West          162    95      67     0
# 29   2015  TEX     AL West          162    88      74     0
# ..    ...  ...         ...          ...   ...     ...   ...
# 714  1999  CIN  NL Central          163    96      67     0
# 715  1998  CIN  NL Central          162    77      85     0
# 716  1997  CIN  NL Central          162    76      86     0
# 717  1996  CIN  NL Central          162    81      81     0
# 718  1995  CIN  NL Central          144    85      59     0
# 719  2019  PIT  NL Central          162    69      93     0
# 720  2018  PIT  NL Central          161    82      79     0
# 721  2017  PIT  NL Central          162    75      87     0
# 722  2016  PIT  NL Central          162    78      83     1
# 723  2015  PIT  NL Central          162    98      64     0
# 724  2014  PIT  NL Central          162    88      74     0
# 725  2013  PIT  NL Central          162    94      68     0
# 726  2012  PIT  NL Central          162    79      83     0
# 727  2011  PIT  NL Central          162    72      90     0
# 728  2010  PIT  NL Central          162    57     105     0
# 729  2009  PIT  NL Central          161    62      99     0
# 730  2008  PIT  NL Central          162    67      95     0
# 731  2007  PIT  NL Central          162    68      94     0
# 732  2006  PIT  NL Central          162    67      95     0
# 733  2005  PIT  NL Central          162    67      95     0
# 734  2004  PIT  NL Central          161    72      89     0
# 735  2003  PIT  NL Central          162    75      87     0
# 736  2002  PIT  NL Central          161    72      89     0
# 737  2001  PIT  NL Central          162    62     100     0
# 738  2000  PIT  NL Central          162    69      93     0
# 739  1999  PIT  NL Central          161    78      83     0
# 740  1998  PIT  NL Central          163    69      93     1
# 741  1997  PIT  NL Central          162    79      83     0
# 742  1996  PIT  NL Central          162    73      89     0
# 743  1995  PIT  NL Central          144    58      86     0
#
#      season_win_loss_%  pythagorean_win_loss_% division_finish  \
# 0                0.660                   0.660        1st of 5
# 1                0.636                   0.675        1st of 5
# 2                0.623                   0.611        1st of 5
# 3                0.519                   0.515        3rd of 5
# 4                0.531                   0.575        2nd of 5
# 5                0.432                   0.437        4th of 5
# 6                0.315                   0.354        5th of 5
# 7                0.340                   0.362        6th of 6
# 8                0.346                   0.384        6th of 6
# 9                0.469                   0.420        4th of 6
# 10               0.457                   0.418        5th of 6
# 11               0.534                   0.481        3rd of 6
# 12               0.451                   0.447        4th of 6
# 13               0.506                   0.510        2nd of 6
# 14               0.549                   0.559        2nd of 6
# 15               0.568                   0.564        2nd of 6
# 16               0.537                   0.579        2nd of 6
# 17               0.519                   0.534        2nd of 6
# 18               0.574                   0.544        1st of 6
# 19               0.444                   0.497        4th of 6
# 20               0.599                   0.590        1st of 6
# 21               0.630                   0.652        1st of 6
# 22               0.519                   0.574        1st of 5
# 23               0.506                   0.477        2nd of 5
# 24               0.528                   0.547        2nd of 5
# 25               0.481                   0.463        3rd of 5
# 26               0.414                   0.436        5th of 5
# 27               0.481                   0.490        3rd of 5
# 28               0.586                   0.505        1st of 5
# 29               0.543                   0.511        1st of 5
# ..                 ...                     ...             ...
# 714              0.589                   0.589        2nd of 6
# 715              0.475                   0.494        4th of 6
# 716              0.469                   0.427        3rd of 5
# 717              0.500                   0.503        3rd of 5
# 718              0.590                   0.582        1st of 5
# 719              0.426                   0.417        5th of 5
# 720              0.509                   0.499        4th of 5
# 721              0.463                   0.459        4th of 5
# 722              0.484                   0.482        3rd of 5
# 723              0.605                   0.571        2nd of 5
# 724              0.543                   0.535        2nd of 5
# 725              0.580                   0.543        2nd of 5
# 726              0.488                   0.484        4th of 6
# 727              0.444                   0.430        4th of 6
# 728              0.352                   0.329        6th of 6
# 729              0.385                   0.415        6th of 6
# 730              0.414                   0.416        6th of 6
# 731              0.420                   0.429        6th of 6
# 732              0.414                   0.435        5th of 6
# 733              0.414                   0.444        6th of 6
# 734              0.447                   0.459        5th of 6
# 735              0.463                   0.472        4th of 6
# 736              0.447                   0.441        4th of 6
# 737              0.383                   0.380        6th of 6
# 738              0.426                   0.448        5th of 6
# 739              0.484                   0.496        3rd of 6
# 740              0.426                   0.455        6th of 6
# 741              0.488                   0.478        2nd of 5
# 742              0.451                   0.468        5th of 5
# 743              0.403                   0.429        5th of 5
#
#     division_game_back  runs_for  runs_against  season_total_attendance  \
# 0                   --       920           640                  2857367
# 1                   --       797           534                  2980549
# 2                   --       896           700                  2403671
# 3                   11       724           701                  2306623
# 4                    2       729           618                  2153585
# 5                   28       629           723                  1751829
# 6                   45       610           848                  1651883
# 7                   42       583           794                  1607733
# 8                   40       615           796                  2067016
# 9                   15       611           729                  2331490
# 10                  17       643           770                  2521076
# 11                  11       712           743                  2779487
# 12                  12       723           813                  3020405
# 13                 1.5       735           719                  3022763
# 14                  11       693           609                  2804760
# 15                  13       803           698                  3087872
# 16                   1       805           677                  2454241
# 17                  13       749           695                  2517357
# 18                  --       847           769                  2904277
# 19                  23       938           944                  3056139
# 20                  --       823           675                  2706017
# 21                  --       874           620                  2458451
# 22                  --       777           660                  2046781
# 23                   6       753           792                  1975888
# 24                   9       747           674                  1363801
# 25                  29       810           878                  2132994
# 26                  36       737           848                  2107107
# 27                  23       799           816                  2507760
# 28                  --       765           757                  2710402
# 29                  --       751           733                  2491875
# ..                 ...       ...           ...                      ...
# 714                1.5       865           711                  2061222
# 715                 25       750           760                  1793649
# 716                  8       651           764                  1785788
# 717                  7       778           773                  1861428
# 718                 --       747           623                  1837649
# 719                 22       758           911                  1491439
# 720                 13       692           693                  1465316
# 721                 17       668           731                  1919447
# 722                 25       729           758                  2249201
# 723                  2       697           596                  2498596
# 724                  2       682           631                  2442564
# 725                  3       634           577                  2256862
# 726                 18       651           674                  2091918
# 727                 24       610           712                  1940429
# 728                 34       587           866                  1613399
# 729               28.5       636           768                  1577853
# 730               30.5       735           884                  1609076
# 731                 17       724           846                  1749142
# 732               16.5       691           797                  1861549
# 733                 33       680           769                  1817245
# 734               32.5       680           744                  1580031
# 735                 13       753           801                  1636751
# 736               24.5       641           730                  1784988
# 737                 31       657           858                  2464870
# 738                 26       793           888                  1748908
# 739               18.5       775           782                  1638023
# 740                 33       650           718                  1560950
# 741                  5       725           760                  1657022
# 742                 15       776           833                  1332150
# 743                 27       629           736                   905517
#
#      average_batter_age  average_pitcher_age  number_of_batters  \
# 0                  28.9                 29.9                 45
# 1                  28.1                 30.0                 41
# 2                  28.8                 28.5                 46
# 3                  26.4                 28.9                 43
# 4                  26.3                 29.4                 46
# 5                  25.4                 27.9                 48
# 6                  25.9                 27.2                 50
# 7                  26.6                 27.2                 50
# 8                  28.2                 27.2                 47
# 9                  29.5                 29.6                 48
# 10                 31.6                 31.2                 42
# 11                 31.1                 30.9                 41
# 12                 31.4                 30.2                 41
# 13                 30.5                 29.8                 39
# 14                 30.3                 30.3                 36
# 15                 31.7                 29.6                 42
# 16                 31.1                 27.6                 44
# 17                 30.1                 27.3                 41
# 18                 30.3                 28.4                 45
# 19                 29.1                 28.0                 46
# 20                 29.8                 27.4                 38
# 21                 29.7                 27.8                 38
# 22                 28.8                 27.0                 41
# 23                 28.2                 28.5                 43
# 24                 28.1                 27.9                 44
# 25                 28.8                 28.3                 53
# 26                 27.4                 30.4                 50
# 27                 28.4                 28.8                 51
# 28                 28.4                 28.8                 52
# 29                 28.7                 28.1                 57
# ..                  ...                  ...                ...
# 714                28.3                 28.0                 35
# 715                27.5                 28.0                 47
# 716                28.2                 29.6                 50
# 717                29.3                 29.2                 48
# 718                28.4                 28.3                 47
# 719                27.4                 27.2                 54
# 720                27.8                 26.5                 48
# 721                28.2                 27.1                 47
# 722                28.9                 28.6                 55
# 723                28.2                 29.6                 46
# 724                27.3                 28.1                 45
# 725                27.9                 28.7                 49
# 726                27.6                 30.2                 49
# 727                27.2                 28.1                 52
# 728                26.5                 28.6                 52
# 729                27.0                 26.3                 49
# 730                28.4                 26.5                 47
# 731                27.2                 27.1                 46
# 732                27.8                 27.0                 42
# 733                27.4                 28.7                 44
# 734                27.2                 27.7                 43
# 735                29.7                 28.3                 46
# 736                27.9                 28.1                 38
# 737                27.8                 28.1                 49
# 738                28.3                 27.1                 46
# 739                28.3                 26.8                 45
# 740                26.7                 26.5                 38
# 741                26.6                 25.7                 43
# 742                28.8                 27.9                 46
# 743                28.3                 26.4                 40
#
#      number_of_pitchers         top_player  \
# 0                    26    A.Bregman (8.4)
# 1                    22    A.Bregman (6.9)
# 2                    27     J.Altuve (8.1)
# 3                    23     J.Altuve (7.7)
# 4                    24    D.Keuchel (6.7)
# 5                    28     J.Altuve (6.1)
# 6                    26     J.Castro (4.1)
# 7                    26    L.Harrell (3.1)
# 8                    23        C.Lee (3.9)
# 9                    25      M.Bourn (5.5)
# 10                   22      M.Bourn (5.0)
# 11                   20    L.Berkman (6.9)
# 12                   21     R.Oswalt (6.6)
# 13                   19    L.Berkman (6.0)
# 14                   17    R.Clemens (8.2)
# 15                   23    L.Berkman (6.0)
# 16                   23    R.Hidalgo (5.7)
# 17                   21     R.Oswalt (6.9)
# 18                   25    L.Berkman (6.5)
# 19                   23    R.Hidalgo (6.3)
# 20                   15    M.Hampton (7.9)
# 21                   18     C.Biggio (6.5)
# 22                   18     C.Biggio (9.4)
# 23                   22    J.Bagwell (7.5)
# 24                   19     C.Biggio (6.3)
# 25                   36      M.Minor (7.6)
# 26                   32      M.Minor (3.8)
# 27                   31    A.Cashner (4.6)
# 28                   31     A.Beltre (6.5)
# 29                   31     A.Beltre (5.9)
# ..                  ...                ...
# 714                  17    M.Cameron (5.5)
# 715                  24     B.Larkin (5.7)
# 716                  25       J.Shaw (3.6)
# 717                  24     B.Larkin (7.2)
# 718                  24    R.Sanders (6.6)
# 719                  34   B.Reynolds (3.9)
# 720                  24    J.Taillon (4.4)
# 721                  24   J.Harrison (3.4)
# 722                  32      S.Marte (4.9)
# 723                  21      S.Marte (5.3)
# 724                  23  A.McCutchen (6.1)
# 725                  29  A.McCutchen (7.9)
# 726                  25  A.McCutchen (6.9)
# 727                  25  A.McCutchen (5.4)
# 728                  28  A.McCutchen (3.8)
# 729                  26      G.Jones (3.3)
# 730                  26     P.Maholm (3.8)
# 731                  25     J.Wilson (3.6)
# 732                  22    F.Sanchez (4.4)
# 733                  19        J.Bay (5.7)
# 734                  22      O.Perez (5.9)
# 735                  23      K.Wells (5.0)
# 736                  19      B.Giles (5.4)
# 737                  22      B.Giles (5.3)
# 738                  24      B.Giles (6.4)
# 739                  21      B.Giles (6.7)
# 740                  17    J.Kendall (5.6)
# 741                  21    F.Cordova (4.3)
# 742                  25     D.Neagle (6.0)
# 743                  21     D.Neagle (4.5)
#
#                                         manager
# 0                              A.Hinch (107-55)
# 1                              A.Hinch (103-59)
# 2                              A.Hinch (101-61)
# 3                               A.Hinch (84-78)
# 4                               A.Hinch (86-76)
# 5        B.Porter (59-79) and T.Lawless (11-13)
# 6                             B.Porter (51-111)
# 7     B.Mills (39-82) and T.DeFrancesco (16-25)
# 8                              B.Mills (56-106)
# 9                               B.Mills (76-86)
# 10           C.Cooper (70-79) and D.Clark (4-9)
# 11                             C.Cooper (86-75)
# 12        P.Garner (58-73) and C.Cooper (15-16)
# 13                             P.Garner (82-80)
# 14                             P.Garner (89-73)
# 15      J.Williams (44-44) and P.Garner (48-26)
# 16                           J.Williams (87-75)
# 17                           J.Williams (84-78)
# 18                            L.Dierker (93-69)
# 19                            L.Dierker (72-90)
# 20      L.Dierker (84-51) and M.Galante (13-14)
# 21                           L.Dierker (102-60)
# 22                            L.Dierker (84-78)
# 23                            T.Collins (82-80)
# 24                            T.Collins (76-68)
# 25                           C.Woodward (78-84)
# 26     J.Banister (64-88) and D.Wakamatsu (3-7)
# 27                           J.Banister (78-84)
# 28                           J.Banister (95-67)
# 29                           J.Banister (88-74)
# ..                                          ...
# 714                            J.McKeon (96-67)
# 715                            J.McKeon (77-85)
# 716       R.Knight (43-56) and J.McKeon (33-30)
# 717                            R.Knight (81-81)
# 718                           D.Johnson (85-59)
# 719         C.Hurdle (69-92) and T.Prince (0-1)
# 720                            C.Hurdle (82-79)
# 721                            C.Hurdle (75-87)
# 722                            C.Hurdle (78-83)
# 723                            C.Hurdle (98-64)
# 724                            C.Hurdle (88-74)
# 725                            C.Hurdle (94-68)
# 726                            C.Hurdle (79-83)
# 727                            C.Hurdle (72-90)
# 728                          J.Russell (57-105)
# 729                           J.Russell (62-99)
# 730                           J.Russell (67-95)
# 731                             J.Tracy (68-94)
# 732                             J.Tracy (67-95)
# 733  L.McClendon (55-81) and P.Mackanin (12-14)
# 734                         L.McClendon (72-89)
# 735                         L.McClendon (75-87)
# 736                         L.McClendon (72-89)
# 737                        L.McClendon (62-100)
# 738                            G.Lamont (69-93)
# 739                            G.Lamont (78-83)
# 740                            G.Lamont (69-93)
# 741                            G.Lamont (79-83)
# 742                           J.Leyland (73-89)
# 743                           J.Leyland (58-86)
#
# [744 rows x 20 columns]

# %%
mlb_df = mlb_df.merge(mlb_franchise[['team', 'year', 'average_batter_age', 'average_pitcher_age', 'league']], on = ['team', 'year'])

# %%
mlb_df.to_csv('../data/clean_data/mlb_df.csv', index=False)
